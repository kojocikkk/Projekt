# %%
import pandas as pd
import numpy as np

# %%
DANE=r'Dane\ames2000_NAfix.csv'
dane=pd.read_csv(DANE)
dane.head(10)
# Out:
#    MS.SubClass MS.Zoning Lot.Frontage  Lot.Area Street Alley Lot.Shape  \
# 0          120        RL           34      3901   Pave  None       Reg
# 1           20        RL           70      8400   Pave  None       Reg
# 2           85        RL           60      7200   Pave  None       Reg
# 3           90        RL           64      7018   Pave  None       Reg
# 4           60        RL          111     16259   Pave  None       Reg
# 5           20        RL           50      4280   Pave  None       IR1
# 6           20        RL          155     20064   Pave  None       IR1
# 7           20        RM           60      7200   Pave  Grvl       Reg
# 8           20        RL           70      9100   Pave  None       Reg
# 9           70   C (all)         None      6449   Pave  None       IR1
#
#   Land.Contour Utilities Lot.Config  ... Pool.Area Pool.QC  Fence  \
# 0          Lvl    AllPub     Inside  ...         0    None   None
# ...

# %%
dane.dtypes
# Out:
# MS.SubClass        int64
# MS.Zoning         object
# Lot.Frontage      object
# Lot.Area           int64
# Street            object
#                    ...
# Mo.Sold            int64
# Yr.Sold            int64
# Sale.Type         object
# Sale.Condition    object
# SalePrice          int64
# Length: 80, dtype: object

# %%
number=dane.select_dtypes([np.number])
number.count()
non_number = dane.select_dtypes([np.object])
non_number.count()
# Out:
# MS.SubClass        2000
# Lot.Area           2000
# Overall.Qual       2000
# Overall.Cond       2000
# Year.Built         2000
# Year.Remod.Add     2000
# X1st.Flr.SF        2000
# X2nd.Flr.SF        2000
# Low.Qual.Fin.SF    2000
# Gr.Liv.Area        2000
# Full.Bath          2000
# Half.Bath          2000
# Bedroom.AbvGr      2000
# Kitchen.AbvGr      2000
# TotRms.AbvGrd      2000
# Fireplaces         2000
# Wood.Deck.SF       2000
# Open.Porch.SF      2000
# Enclosed.Porch     2000
# X3Ssn.Porch        2000
# Screen.Porch       2000
# Pool.Area          2000
# Misc.Val           2000
# Mo.Sold            2000
# Yr.Sold            2000
# SalePrice          2000
# dtype: int64

# %%
missings = len(dane) - dane.count().sort_values(ascending=True)
missings
# Out:
# Mas.Vnr.Type      16
# Bsmt.Exposure      3
# Garage.Finish      2
# BsmtFin.Type.2     2
# Bsmt.Cond          1
#                   ..
# Exterior.1st       0
# Roof.Matl          0
# Roof.Style         0
# Year.Built         0
# SalePrice          0
# Length: 80, dtype: int64

# %%
dane_copy =dane.copy()
dane_copy.head(2)
# Out:
#    MS.SubClass MS.Zoning Lot.Frontage  Lot.Area Street Alley Lot.Shape  \
# 0          120        RL           34      3901   Pave  None       Reg
# 1           20        RL           70      8400   Pave  None       Reg
#
#   Land.Contour Utilities Lot.Config  ... Pool.Area Pool.QC  Fence  \
# 0          Lvl    AllPub     Inside  ...         0    None   None
# 1          Lvl    AllPub     Corner  ...         0    None  MnPrv
#
#   Misc.Feature Misc.Val Mo.Sold  Yr.Sold  Sale.Type  Sale.Condition  SalePrice
# 0         None        0       8     2007        New         Partial     204000
# 1         None        0       4     2010        WD           Normal     126000
#
# [2 rows x 80 columns]

# %%
def empty_fill(dane):
    for column in dane_copy.columns:
        dane_copy[column] = dane_copy[column].fillna("missing")
     
        return dane_copy
def empty_number(dane):
    
dane_copy
# Out:
#       MS.SubClass MS.Zoning Lot.Frontage  Lot.Area Street Alley Lot.Shape  \
# 0             120        RL           34      3901   Pave  None       Reg
# 1              20        RL           70      8400   Pave  None       Reg
# 2              85        RL           60      7200   Pave  None       Reg
# 3              90        RL           64      7018   Pave  None       Reg
# 4              60        RL          111     16259   Pave  None       Reg
# ...           ...       ...          ...       ...    ...   ...       ...
# 1995           80        RL           80      8000   Pave  None       Reg
# 1996          180        RM           35      3675   Pave  None       Reg
# 1997           60        RL           76     10142   Pave  None       IR1
# 1998           85        RL         None      7252   Pave  None       IR1
# 1999          160        FV           34      2998   Pave  None       Reg
#
#      Land.Contour Utilities Lot.Config  ... Pool.Area Pool.QC  Fence  \
# ...

# %%
missings = len(dane_copy) - dane_copy.count().sort_values(ascending=True)
missings
# Out:
# MS.SubClass       0
# Garage.Type       0
# Fireplace.Qu      0
# Fireplaces        0
# Functional        0
#                  ..
# Exterior.2nd      0
# Exterior.1st      0
# Roof.Matl         0
# Sale.Condition    0
# SalePrice         0
# Length: 80, dtype: int64
